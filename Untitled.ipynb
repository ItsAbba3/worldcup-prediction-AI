# %%
from predict import predict_upcoming_match

result = predict_upcoming_match(
    match_name="United States vs Paraguay",
    venue="SoFi Stadium",
    lineup_home=[
        "Matt Freese",
        "Alex Freeman",
        "Chris Richards",
        "Tim Ream",
        "Antonee Robinson",
        "Sergino Dest",
        "Tyler Adams",
        "Weston McKennie",
        "Malik Tillman",
        "Christian Pulisic",
        "Folarin Balogun"
    ],
    lineup_away=[
        "Roberto Fernandez",
        "Juan Caceres",
        "Gustavo Gomez",
        "Omar Alderete",
        "Junior Alonso",
        "Andres Cubas",
        "Diego Gomez",
        "Alejandro Romero Gamarra",
        "Miguel Almiron",
        "Julio Enciso",
        "Antonio Sanabria"
    ]
)

print(result)
# Out:
# MatchPrediction(match_name='United States vs Paraguay', home='United States', away='Paraguay', venue='SoFi Stadium', city='Los Angeles', altitude_m=30.0, travel_home_km=0.0, travel_away_km=0.0, rest_home_days=7.0, rest_away_days=7.0, xg_home=1.546, xg_away=1.379, prob_home_win=0.3995, prob_draw=0.2682, prob_away_win=0.3323, top_scorelines=[{'score': '1-1', 'probability': 0.1116}, {'score': '0-0', 'probability': 0.0887}, {'score': '2-1', 'probability': 0.0782}, {'score': '1-0', 'probability': 0.0752}, {'score': '1-2', 'probability': 0.0679}, {'score': '0-1', 'probability': 0.0678}, {'score': '2-0', 'probability': 0.0637}, {'score': '0-2', 'probability': 0.0542}, {'score': '2-2', 'probability': 0.0509}, {'score': '3-1', 'probability': 0.0381}], lineup_home={'players': ['Matt Freese', 'Alex Freeman', 'Chris Richards', 'Tim Ream', 'Antonee Robinson', 'Sergino Dest', 'Tyler Adams', 'Weston McKennie', 'Malik Tillman', 'Christian Pulisic', 'Folarin Balogun'], 'lineup_rating': 66.6, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Matt Freese', 'matched': 'Matt Freese', 'ovr': 64.1948051948052, 'pos': 'MID'}, {'input': 'Alex Freeman', 'matched': 'A. Freeman', 'ovr': 65.0, 'pos': 'RB'}, {'input': 'Chris Richards', 'matched': 'Chris Richards', 'ovr': 64.1948051948052, 'pos': 'MID'}, {'input': 'Tim Ream', 'matched': 'T. Ream', 'ovr': 72.0, 'pos': 'CB, LB'}, {'input': 'Antonee Robinson', 'matched': 'Antonee Robinson', 'ovr': 82.0, 'pos': 'LB, LM'}, {'input': 'Sergino Dest', 'matched': 'Sergino Dest', 'ovr': 64.1948051948052, 'pos': 'MID'}, {'input': 'Tyler Adams', 'matched': 'Tyler Adams', 'ovr': 64.1948051948052, 'pos': 'MID'}, {'input': 'Weston McKennie', 'matched': 'Weston McKennie', 'ovr': 64.1948051948052, 'pos': 'MID'}, {'input': 'Malik Tillman', 'matched': 'Malik Tillman', 'ovr': 64.1948051948052, 'pos': 'MID'}, {'input': 'Christian Pulisic', 'matched': 'Christian Pulisic', 'ovr': 64.1948051948052, 'pos': 'MID'}, {'input': 'Folarin Balogun', 'matched': 'Folarin Balogun', 'ovr': 64.1948051948052, 'pos': 'MID'}]}, lineup_away={'players': ['Roberto Fernandez', 'Juan Caceres', 'Gustavo Gomez', 'Omar Alderete', 'Junior Alonso', 'Andres Cubas', 'Diego Gomez', 'Alejandro Romero Gamarra', 'Miguel Almiron', 'Julio Enciso', 'Antonio Sanabria'], 'lineup_rating': 68.26, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Roberto Fernandez', 'matched': 'Roberto Fernández Jaén', 'ovr': 74.0, 'pos': 'ST'}, {'input': 'Juan Caceres', 'matched': 'Juan Caceres', 'ovr': 66.36, 'pos': 'MID'}, {'input': 'Gustavo Gomez', 'matched': 'Gustavo Gomez', 'ovr': 66.36, 'pos': 'MID'}, {'input': 'Omar Alderete', 'matched': 'O. Alderete', 'ovr': 78.0, 'pos': 'CB'}, {'input': 'Junior Alonso', 'matched': 'Julio Alonso', 'ovr': 68.0, 'pos': 'LB, LM'}, {'input': 'Andres Cubas', 'matched': 'Andres Cubas', 'ovr': 66.36, 'pos': 'MID'}, {'input': 'Diego Gomez', 'matched': 'Diego Gomez', 'ovr': 66.36, 'pos': 'MID'}, {'input': 'Alejandro Romero Gamarra', 'matched': 'Alejandro Romero Gamarra', 'ovr': 66.36, 'pos': 'MID'}, {'input': 'Miguel Almiron', 'matched': 'Miguel Almiron', 'ovr': 66.36, 'pos': 'MID'}, {'input': 'Julio Enciso', 'matched': 'Julio Enciso', 'ovr': 66.36, 'pos': 'MID'}, {'input': 'Antonio Sanabria', 'matched': 'Antonio Sanabria', 'ovr': 66.36, 'pos': 'MID'}]}, model_version='dixon-coles-nb-v2')

# %%
from predict import predict_upcoming_match

result = predict_upcoming_match(
    match_name="Canada vs Bosnia and Herzegovina",
    venue="BMO Field",
    lineup_home=[
        "Maxime Crepeau",
        "Alistair Johnston",
        "Luc De Fougerolles",
        "Derek Cornelius",
        "Richie Laryea",
        "Tajon Buchanan",
        "Stephen Eustaquio",
        "Ismael Kone",
        "Liam Millar",
        "Jonathan David",
        "Cyle Larin"
    ],
    lineup_away=[
        "Nikola Vasilj",
        "Amar Dedic",
        "Nikola Katic",
        "Tarik Muharemovic",
        "Sead Kolasinac",
        "Esmir Bajraktarevic",
        "Benjamin Tahirovic",
        "Ivan Basic",
        "Amar Memic",
        "Ermedin Demirovic",
        "Edin Dzeko"
    ]
)

print(result)
# Out:
# MatchPrediction(match_name='Canada vs Bosnia and Herzegovina', home='Canada', away='Bosnia and Herzegovina', venue='BMO Field', city='Toronto', altitude_m=76.0, travel_home_km=0.0, travel_away_km=0.0, rest_home_days=7.0, rest_away_days=7.0, xg_home=1.713, xg_away=0.727, prob_home_win=0.5754, prob_draw=0.2708, prob_away_win=0.1538, top_scorelines=[{'score': '1-0', 'probability': 0.1325}, {'score': '0-0', 'probability': 0.1201}, {'score': '2-0', 'probability': 0.1195}, {'score': '1-1', 'probability': 0.1146}, {'score': '2-1', 'probability': 0.0805}, {'score': '3-0', 'probability': 0.0715}, {'score': '0-1', 'probability': 0.0566}, {'score': '3-1', 'probability': 0.0455}, {'score': '1-2', 'probability': 0.0361}, {'score': '2-2', 'probability': 0.0319}], lineup_home={'players': ['Maxime Crepeau', 'Alistair Johnston', 'Luc De Fougerolles', 'Derek Cornelius', 'Richie Laryea', 'Tajon Buchanan', 'Stephen Eustaquio', 'Ismael Kone', 'Liam Millar', 'Jonathan David', 'Cyle Larin'], 'lineup_rating': 64.82, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Maxime Crepeau', 'matched': 'Maxime Crépeau', 'ovr': 69.0, 'pos': 'GK'}, {'input': 'Alistair Johnston', 'matched': 'Alistair Johnston', 'ovr': 63.2, 'pos': 'MID'}, {'input': 'Luc De Fougerolles', 'matched': 'L. De Fougerolles', 'ovr': 60.0, 'pos': 'CB, RB, LB'}, {'input': 'Derek Cornelius', 'matched': 'D. Cornelius', 'ovr': 74.0, 'pos': 'CB'}, {'input': 'Richie Laryea', 'matched': 'Richie Laryea', 'ovr': 63.2, 'pos': 'MID'}, {'input': 'Tajon Buchanan', 'matched': 'Tajon Buchanan', 'ovr': 63.2, 'pos': 'MID'}, {'input': 'Stephen Eustaquio', 'matched': 'Stephen Eustáquio', 'ovr': 77.0, 'pos': 'CDM, CM, CB'}, {'input': 'Ismael Kone', 'matched': 'Ismael Konate', 'ovr': 57.0, 'pos': 'ST'}, {'input': 'Liam Millar', 'matched': 'Liam Möller', 'ovr': 60.0, 'pos': 'CAM, RW, CM'}, {'input': 'Jonathan David', 'matched': 'Jonathan David', 'ovr': 63.2, 'pos': 'MID'}, {'input': 'Cyle Larin', 'matched': 'Cyle Larin', 'ovr': 63.2, 'pos': 'MID'}]}, lineup_away={'players': ['Nikola Vasilj', 'Amar Dedic', 'Nikola Katic', 'Tarik Muharemovic', 'Sead Kolasinac', 'Esmir Bajraktarevic', 'Benjamin Tahirovic', 'Ivan Basic', 'Amar Memic', 'Ermedin Demirovic', 'Edin Dzeko'], 'lineup_rating': 72.97, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Nikola Vasilj', 'matched': 'Nikola Vasilj', 'ovr': 77.0, 'pos': 'GK'}, {'input': 'Amar Dedic', 'matched': 'Amar Dedić', 'ovr': 74.0, 'pos': 'RB, LB, RM'}, {'input': 'Nikola Katic', 'matched': 'Nikola Katić', 'ovr': 69.0, 'pos': 'CB'}, {'input': 'Tarik Muharemovic', 'matched': 'Tarik Muharemović', 'ovr': 70.0, 'pos': 'CB'}, {'input': 'Sead Kolasinac', 'matched': 'Sead Kolašinac', 'ovr': 79.0, 'pos': 'CB'}, {'input': 'Esmir Bajraktarevic', 'matched': 'Esmir Bajraktarević', 'ovr': 67.0, 'pos': 'RW, RM'}, {'input': 'Benjamin Tahirovic', 'matched': 'Benjamin Tahirović', 'ovr': 67.0, 'pos': 'CDM, CM'}, {'input': 'Ivan Basic', 'matched': 'Ivan Basic', 'ovr': 66.61538461538461, 'pos': 'MID'}, {'input': 'Amar Memic', 'matched': 'Amar Memić', 'ovr': 72.0, 'pos': 'RM, LM, RW'}, {'input': 'Ermedin Demirovic', 'matched': 'Ermedin Demirović', 'ovr': 80.0, 'pos': 'ST'}, {'input': 'Edin Dzeko', 'matched': 'Edin Džeko', 'ovr': 81.0, 'pos': 'ST'}]}, model_version='dixon-coles-nb-v2')

# %%
from predict import predict_upcoming_match

result = predict_upcoming_match(
    match_name="South Korea vs Czech Republic",
    venue="Guadalajara Stadium",
    lineup_home=[
        "Kim Seung-gyu",
        "Lee Gi-hyeok",
        "Han-beom Lee",
        "Kim Min-jae",
        "Lee Tae-seok",
        "Young-woo Seol",
        "Paik Seung-ho",
        "Hwang In-beom",
        "Lee Jae-sung",
        "Lee Kang-in",
        "Son Heung-min"
    ],
    lineup_away=[
        "Matej Kovar",
        "Robin Hranac",
        "Stepan Chaloupek",
        "Ladislav Krejci",
        "Vladimir Coufal",
        "Tomas Soucek",
        "David Pavelka",
        "Lukas Provod",
        "David Jurasek",
        "Pavel Sulc",
        "Patrik Schick"
    ]
)

print(result)
# Out:
# MatchPrediction(match_name='South Korea vs Czech Republic', home='South Korea', away='Czech Republic', venue='Guadalajara Stadium', city='Guadalajara', altitude_m=1568.0, travel_home_km=0.0, travel_away_km=0.0, rest_home_days=7.0, rest_away_days=7.0, xg_home=1.331, xg_away=1.18, prob_home_win=0.3824, prob_draw=0.2919, prob_away_win=0.3257, top_scorelines=[{'score': '1-1', 'probability': 0.1254}, {'score': '0-0', 'probability': 0.1113}, {'score': '1-0', 'probability': 0.0944}, {'score': '0-1', 'probability': 0.0865}, {'score': '2-1', 'probability': 0.0766}, {'score': '2-0', 'probability': 0.0695}, {'score': '1-2', 'probability': 0.0658}, {'score': '0-2', 'probability': 0.0575}, {'score': '2-2', 'probability': 0.0449}, {'score': '3-1', 'probability': 0.0329}], lineup_home={'players': ['Kim Seung-gyu', 'Lee Gi-hyeok', 'Han-beom Lee', 'Kim Min-jae', 'Lee Tae-seok', 'Young-woo Seol', 'Paik Seung-ho', 'Hwang In-beom', 'Lee Jae-sung', 'Lee Kang-in', 'Son Heung-min'], 'lineup_rating': 70.55, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Kim Seung-gyu', 'matched': 'Kim Seung-gyu', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Lee Gi-hyeok', 'matched': 'Lee Gi Hyeok', 'ovr': 69.0, 'pos': 'CB, CM, RM, CDM'}, {'input': 'Han-beom Lee', 'matched': 'Lee Han Beom', 'ovr': 69.0, 'pos': 'CB'}, {'input': 'Kim Min-jae', 'matched': 'Kim Min Jae', 'ovr': 48.0, 'pos': 'CDM, CM'}, {'input': 'Lee Tae-seok', 'matched': 'Lee Tae Seok', 'ovr': 69.0, 'pos': 'LB, LM'}, {'input': 'Young-woo Seol', 'matched': 'Young-woo Seol', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Paik Seung-ho', 'matched': 'Paik Seung Ho', 'ovr': 72.0, 'pos': 'CDM, CM'}, {'input': 'Hwang In-beom', 'matched': 'Hwang In Beom', 'ovr': 77.0, 'pos': 'CM, CDM, CAM'}, {'input': 'Lee Jae-sung', 'matched': 'Lee Jae Sung', 'ovr': 77.0, 'pos': 'CAM, CM'}, {'input': 'Lee Kang-in', 'matched': 'Lee Kang In', 'ovr': 79.0, 'pos': 'RW, CM, RM'}, {'input': 'Son Heung-min', 'matched': 'Son Heung-min', 'ovr': 72.0, 'pos': 'MID'}]}, lineup_away={'players': ['Matej Kovar', 'Robin Hranac', 'Stepan Chaloupek', 'Ladislav Krejci', 'Vladimir Coufal', 'Tomas Soucek', 'David Pavelka', 'Lukas Provod', 'David Jurasek', 'Pavel Sulc', 'Patrik Schick'], 'lineup_rating': 74.82, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Matej Kovar', 'matched': 'Matej Kovar', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Robin Hranac', 'matched': 'Robin Hranáč', 'ovr': 71.0, 'pos': 'CB'}, {'input': 'Stepan Chaloupek', 'matched': 'Stepan Chaloupek', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Ladislav Krejci', 'matched': 'Ladislav Krejčí', 'ovr': 78.0, 'pos': 'CB, CDM'}, {'input': 'Vladimir Coufal', 'matched': 'Vladimír Coufal', 'ovr': 73.0, 'pos': 'RB, RM'}, {'input': 'Tomas Soucek', 'matched': 'Tomas Soucek', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'David Pavelka', 'matched': 'David Pavelka', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Lukas Provod', 'matched': 'Lukáš Provod', 'ovr': 78.0, 'pos': 'CAM, CM, LM'}, {'input': 'David Jurasek', 'matched': 'David Jurásek', 'ovr': 73.0, 'pos': 'LB, LM'}, {'input': 'Pavel Sulc', 'matched': 'Pavel Šulc', 'ovr': 77.0, 'pos': 'CAM, LM, RM, CM'}, {'input': 'Patrik Schick', 'matched': 'Patrik Schick', 'ovr': 85.0, 'pos': 'ST'}]}, model_version='dixon-coles-nb-v2')

# %%
from predict import predict_upcoming_match

result = predict_upcoming_match(
    match_name="Netherlands vs Japan",
    venue="AT&T Stadium",
    lineup_home=[
        "Bart Verbruggen",
        "Denzel Dumfries",
        "Jan Paul van Hecke",
        "Virgil van Dijk",
        "Micky van de Ven",
        "Tijjani Reijnders",
        "Ryan Gravenberch",
        "Frenkie de Jong",
        "Crysencio Summerville",
        "Donyell Malen",
        "Cody Gakpo"
    ],
    lineup_away=[
        "Zion Suzuki",
        "Shogo Watanabe",
        "Ko Itakura",
        "Hiroki Ito",
        "Ritsu Doan",
        "Kaishu Sano",
        "Daichi Kamada",
        "Keito Nakamura",
        "Junya Ito",
        "Takefusa Kubo",
        "Ayase Ueda"
    ]
)

print(result)
# Out:
# MatchPrediction(match_name='Netherlands vs Japan', home='Netherlands', away='Japan', venue='AT&T Stadium', city='Dallas', altitude_m=199.0, travel_home_km=0.0, travel_away_km=0.0, rest_home_days=7.0, rest_away_days=7.0, xg_home=1.182, xg_away=1.137, prob_home_win=0.3583, prob_draw=0.3037, prob_away_win=0.338, top_scorelines=[{'score': '1-1', 'probability': 0.1302}, {'score': '0-0', 'probability': 0.1265}, {'score': '1-0', 'probability': 0.1089}, {'score': '0-1', 'probability': 0.0992}, {'score': '2-0', 'probability': 0.0703}, {'score': '0-2', 'probability': 0.0691}, {'score': '1-2', 'probability': 0.0672}, {'score': '2-1', 'probability': 0.0667}, {'score': '2-2', 'probability': 0.039}, {'score': '3-0', 'probability': 0.029}], lineup_home={'players': ['Bart Verbruggen', 'Denzel Dumfries', 'Jan Paul van Hecke', 'Virgil van Dijk', 'Micky van de Ven', 'Tijjani Reijnders', 'Ryan Gravenberch', 'Frenkie de Jong', 'Crysencio Summerville', 'Donyell Malen', 'Cody Gakpo'], 'lineup_rating': 77.75, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Bart Verbruggen', 'matched': 'Bart Verbruggen', 'ovr': 78.0, 'pos': 'GK'}, {'input': 'Denzel Dumfries', 'matched': 'Denzel Dumfries', 'ovr': 68.57303370786516, 'pos': 'MID'}, {'input': 'Jan Paul van Hecke', 'matched': 'Jan Paul van Hecke', 'ovr': 80.0, 'pos': 'CB'}, {'input': 'Virgil van Dijk', 'matched': 'Virgil van Dijk', 'ovr': 90.0, 'pos': 'CB'}, {'input': 'Micky van de Ven', 'matched': 'Micky van de Ven', 'ovr': 82.0, 'pos': 'CB, LB, LM'}, {'input': 'Tijjani Reijnders', 'matched': 'Tijjani Reijnders', 'ovr': 68.57303370786516, 'pos': 'MID'}, {'input': 'Ryan Gravenberch', 'matched': 'R. Gravenberch', 'ovr': 85.0, 'pos': 'CDM, CM'}, {'input': 'Frenkie de Jong', 'matched': 'Frenkie de Jong', 'ovr': 87.0, 'pos': 'CM, CDM'}, {'input': 'Crysencio Summerville', 'matched': 'Crysencio Summerville', 'ovr': 68.57303370786516, 'pos': 'MID'}, {'input': 'Donyell Malen', 'matched': 'Donyell Malen', 'ovr': 79.0, 'pos': 'RM, RW, LM'}, {'input': 'Cody Gakpo', 'matched': 'Cody Gakpo', 'ovr': 68.57303370786516, 'pos': 'MID'}]}, lineup_away={'players': ['Zion Suzuki', 'Shogo Watanabe', 'Ko Itakura', 'Hiroki Ito', 'Ritsu Doan', 'Kaishu Sano', 'Daichi Kamada', 'Keito Nakamura', 'Junya Ito', 'Takefusa Kubo', 'Ayase Ueda'], 'lineup_rating': 69.43, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Zion Suzuki', 'matched': 'Zion Suzuki', 'ovr': 67.85714285714286, 'pos': 'MID'}, {'input': 'Shogo Watanabe', 'matched': 'Shogo Watanabe', 'ovr': 67.85714285714286, 'pos': 'MID'}, {'input': 'Ko Itakura', 'matched': 'K. Itakura', 'ovr': 77.0, 'pos': 'CB, CDM'}, {'input': 'Hiroki Ito', 'matched': 'Hiroki Ito', 'ovr': 67.85714285714286, 'pos': 'MID'}, {'input': 'Ritsu Doan', 'matched': 'Ritsu Doan', 'ovr': 67.85714285714286, 'pos': 'MID'}, {'input': 'Kaishu Sano', 'matched': 'Kaishu Sano', 'ovr': 67.85714285714286, 'pos': 'MID'}, {'input': 'Daichi Kamada', 'matched': 'Daichi Kamada', 'ovr': 67.85714285714286, 'pos': 'MID'}, {'input': 'Keito Nakamura', 'matched': 'Keito Nakamura中村 敬斗', 'ovr': 76.0, 'pos': 'LM, LW'}, {'input': 'Junya Ito', 'matched': 'Junya Ito', 'ovr': 67.85714285714286, 'pos': 'MID'}, {'input': 'Takefusa Kubo', 'matched': 'Takefusa Kubo', 'ovr': 67.85714285714286, 'pos': 'MID'}, {'input': 'Ayase Ueda', 'matched': 'Ayase Ueda', 'ovr': 67.85714285714286, 'pos': 'MID'}]}, model_version='dixon-coles-nb-v2')

# %%
from predict import predict_upcoming_match

result = predict_upcoming_match(
    match_name="Netherlands vs Japan",
    venue="AT&T Stadium",
    lineup_home=[
        "Bart Verbruggen",
        "Denzel Dumfries",
        "Jan Paul van Hecke",
        "Virgil van Dijk",
        "Micky van de Ven",
        "Tijjani Reijnders",
        "Ryan Gravenberch",
        "Frenkie de Jong",
        "Crysencio Summerville",
        "Donyell Malen",
        "Cody Gakpo"
    ],
    lineup_away=[
        "Zion Suzuki",
        "Shogo Watanabe",
        "Ko Itakura",
        "Hiroki Ito",
        "Ritsu Doan",
        "Kaishu Sano",
        "Daichi Kamada",
        "Keito Nakamura",
        "Junya Ito",
        "Takefusa Kubo",
        "Ayase Ueda"
    ]
)

print(result)
# Out:
# MatchPrediction(match_name='Netherlands vs Japan', home='Netherlands', away='Japan', venue='AT&T Stadium', city='Dallas', altitude_m=199.0, travel_home_km=0.0, travel_away_km=0.0, rest_home_days=7.0, rest_away_days=7.0, xg_home=1.182, xg_away=1.137, prob_home_win=0.3552, prob_draw=0.3053, prob_away_win=0.3395, top_scorelines=[{'score': '1-1', 'probability': 0.1314}, {'score': '0-0', 'probability': 0.1299}, {'score': '1-0', 'probability': 0.1098}, {'score': '0-1', 'probability': 0.1001}, {'score': '2-0', 'probability': 0.0695}, {'score': '1-2', 'probability': 0.0685}, {'score': '2-1', 'probability': 0.068}, {'score': '0-2', 'probability': 0.0654}, {'score': '2-2', 'probability': 0.0359}, {'score': '3-1', 'probability': 0.0289}], lineup_home={'players': ['Bart Verbruggen', 'Denzel Dumfries', 'Jan Paul van Hecke', 'Virgil van Dijk', 'Micky van de Ven', 'Tijjani Reijnders', 'Ryan Gravenberch', 'Frenkie de Jong', 'Crysencio Summerville', 'Donyell Malen', 'Cody Gakpo'], 'lineup_rating': 77.75, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Bart Verbruggen', 'matched': 'Bart Verbruggen', 'ovr': 78.0, 'pos': 'GK'}, {'input': 'Denzel Dumfries', 'matched': 'Denzel Dumfries', 'ovr': 68.57303370786516, 'pos': 'MID'}, {'input': 'Jan Paul van Hecke', 'matched': 'Jan Paul van Hecke', 'ovr': 80.0, 'pos': 'CB'}, {'input': 'Virgil van Dijk', 'matched': 'Virgil van Dijk', 'ovr': 90.0, 'pos': 'CB'}, {'input': 'Micky van de Ven', 'matched': 'Micky van de Ven', 'ovr': 82.0, 'pos': 'CB, LB, LM'}, {'input': 'Tijjani Reijnders', 'matched': 'Tijjani Reijnders', 'ovr': 68.57303370786516, 'pos': 'MID'}, {'input': 'Ryan Gravenberch', 'matched': 'R. Gravenberch', 'ovr': 85.0, 'pos': 'CDM, CM'}, {'input': 'Frenkie de Jong', 'matched': 'Frenkie de Jong', 'ovr': 87.0, 'pos': 'CM, CDM'}, {'input': 'Crysencio Summerville', 'matched': 'Crysencio Summerville', 'ovr': 68.57303370786516, 'pos': 'MID'}, {'input': 'Donyell Malen', 'matched': 'Donyell Malen', 'ovr': 79.0, 'pos': 'RM, RW, LM'}, {'input': 'Cody Gakpo', 'matched': 'Cody Gakpo', 'ovr': 68.57303370786516, 'pos': 'MID'}]}, lineup_away={'players': ['Zion Suzuki', 'Shogo Watanabe', 'Ko Itakura', 'Hiroki Ito', 'Ritsu Doan', 'Kaishu Sano', 'Daichi Kamada', 'Keito Nakamura', 'Junya Ito', 'Takefusa Kubo', 'Ayase Ueda'], 'lineup_rating': 69.43, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Zion Suzuki', 'matched': 'Zion Suzuki', 'ovr': 67.85714285714286, 'pos': 'MID'}, {'input': 'Shogo Watanabe', 'matched': 'Shogo Watanabe', 'ovr': 67.85714285714286, 'pos': 'MID'}, {'input': 'Ko Itakura', 'matched': 'K. Itakura', 'ovr': 77.0, 'pos': 'CB, CDM'}, {'input': 'Hiroki Ito', 'matched': 'Hiroki Ito', 'ovr': 67.85714285714286, 'pos': 'MID'}, {'input': 'Ritsu Doan', 'matched': 'Ritsu Doan', 'ovr': 67.85714285714286, 'pos': 'MID'}, {'input': 'Kaishu Sano', 'matched': 'Kaishu Sano', 'ovr': 67.85714285714286, 'pos': 'MID'}, {'input': 'Daichi Kamada', 'matched': 'Daichi Kamada', 'ovr': 67.85714285714286, 'pos': 'MID'}, {'input': 'Keito Nakamura', 'matched': 'Keito Nakamura中村 敬斗', 'ovr': 76.0, 'pos': 'LM, LW'}, {'input': 'Junya Ito', 'matched': 'Junya Ito', 'ovr': 67.85714285714286, 'pos': 'MID'}, {'input': 'Takefusa Kubo', 'matched': 'Takefusa Kubo', 'ovr': 67.85714285714286, 'pos': 'MID'}, {'input': 'Ayase Ueda', 'matched': 'Ayase Ueda', 'ovr': 67.85714285714286, 'pos': 'MID'}]}, model_version='dixon-coles-nb-v2')

# %%
from predict import predict_upcoming_match

result = predict_upcoming_match(
    match_name="Ivory Coast vs Ecuador",
    venue="Lincoln Financial Field",
    lineup_home=[
        "Yahia Fofana",
        "Guela Doue",
        "Wilfried Singo",
        "Emmanuel Agbadou",
        "Ghislain Konan",
        "Ibrahim Sangare",
        "Franck Kessie",
        "Oumar Diakite",
        "Amad Diallo",
        "Simon Adingra",
        "Elye Wahi"
    ],
    lineup_away=[
        "Hernan Galindez",
        "Joel Ordonez",
        "Willian Pacho",
        "Piero Hincapie",
        "Pervis Estupinan",
        "Moises Caicedo",
        "Pedro Vite",
        "Nilson Angulo",
        "Gonzalo Plata",
        "John Yeboah",
        "Enner Valencia"
    ]
)

print(result)
# Out:
# MatchPrediction(match_name='Ivory Coast vs Ecuador', home='Ivory Coast', away='Ecuador', venue='Lincoln Financial Field', city='Philadelphia', altitude_m=12.0, travel_home_km=0.0, travel_away_km=0.0, rest_home_days=7.0, rest_away_days=7.0, xg_home=1.052, xg_away=0.886, prob_home_win=0.3722, prob_draw=0.3368, prob_away_win=0.291, top_scorelines=[{'score': '0-0', 'probability': 0.1768}, {'score': '1-0', 'probability': 0.1383}, {'score': '1-1', 'probability': 0.1307}, {'score': '0-1', 'probability': 0.1136}, {'score': '2-0', 'probability': 0.078}, {'score': '2-1', 'probability': 0.062}, {'score': '0-2', 'probability': 0.0567}, {'score': '1-2', 'probability': 0.0559}, {'score': '3-0', 'probability': 0.0317}, {'score': '2-2', 'probability': 0.0239}], lineup_home={'players': ['Yahia Fofana', 'Guela Doue', 'Wilfried Singo', 'Emmanuel Agbadou', 'Ghislain Konan', 'Ibrahim Sangare', 'Franck Kessie', 'Oumar Diakite', 'Amad Diallo', 'Simon Adingra', 'Elye Wahi'], 'lineup_rating': 73.64, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Yahia Fofana', 'matched': 'Yahia Fofana', 'ovr': 76.0, 'pos': 'GK'}, {'input': 'Guela Doue', 'matched': 'Guéla Doué', 'ovr': 77.0, 'pos': 'RB, CB, RM'}, {'input': 'Wilfried Singo', 'matched': 'Wilfried Singo', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Emmanuel Agbadou', 'matched': 'Emmanuel Agbadou', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Ghislain Konan', 'matched': 'Ghislain Konan', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Ibrahim Sangare', 'matched': 'Ibrahim Sangaré', 'ovr': 77.0, 'pos': 'CDM, CM'}, {'input': 'Franck Kessie', 'matched': 'Franck Kessie', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Oumar Diakite', 'matched': 'Oumar Diakité', 'ovr': 72.0, 'pos': 'ST'}, {'input': 'Amad Diallo', 'matched': 'Amad Diallo', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Simon Adingra', 'matched': 'Simon Adingra', 'ovr': 76.0, 'pos': 'RM, LM, RW'}, {'input': 'Elye Wahi', 'matched': 'Elye Wahi', 'ovr': 72.0, 'pos': 'MID'}]}, lineup_away={'players': ['Hernan Galindez', 'Joel Ordonez', 'Willian Pacho', 'Piero Hincapie', 'Pervis Estupinan', 'Moises Caicedo', 'Pedro Vite', 'Nilson Angulo', 'Gonzalo Plata', 'John Yeboah', 'Enner Valencia'], 'lineup_rating': 67.3, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Hernan Galindez', 'matched': 'Hernan Galindez', 'ovr': 67.3, 'pos': 'MID'}, {'input': 'Joel Ordonez', 'matched': 'Joel Ordonez', 'ovr': 67.3, 'pos': 'MID'}, {'input': 'Willian Pacho', 'matched': 'Willian Pacho', 'ovr': 67.3, 'pos': 'MID'}, {'input': 'Piero Hincapie', 'matched': 'Piero Hincapie', 'ovr': 67.3, 'pos': 'MID'}, {'input': 'Pervis Estupinan', 'matched': 'Pervis Estupinan', 'ovr': 67.3, 'pos': 'MID'}, {'input': 'Moises Caicedo', 'matched': 'Moises Caicedo', 'ovr': 67.3, 'pos': 'MID'}, {'input': 'Pedro Vite', 'matched': 'Pedro Vite', 'ovr': 67.3, 'pos': 'MID'}, {'input': 'Nilson Angulo', 'matched': 'Nilson Angulo', 'ovr': 67.3, 'pos': 'MID'}, {'input': 'Gonzalo Plata', 'matched': 'Gonzalo Plata', 'ovr': 67.3, 'pos': 'MID'}, {'input': 'John Yeboah', 'matched': 'John Yeboah', 'ovr': 67.3, 'pos': 'MID'}, {'input': 'Enner Valencia', 'matched': 'Enner Valencia', 'ovr': 67.3, 'pos': 'MID'}]}, model_version='dixon-coles-nb-v2')

# %%
from predict import predict_upcoming_match

result = predict_upcoming_match(
    match_name="Sweden vs Tunisia",
    venue="Estadio BBVA",
    lineup_home=[
        "Kristoffer Nordfeldt",
        "Victor Lindelof",
        "Isak Hien",
        "Gustaf Lagerbielke",
        "Daniel Svensson",
        "Hugo Larsson",
        "Yasin Ayari",
        "Gabriel Gudmundsson",
        "Anthony Elanga",
        "Alexander Isak",
        "Viktor Gyokeres"
    ],
    lineup_away=[
        "Aymen Dahmen",
        "Montassar Talbi",
        "Dylan Bronn",
        "Hamza Ben Abda",
        "Ali Abdi",
        "Ellyes Skhiri",
        "Hannibal Mejbri",
        "Anis Ben Slimane",
        "Mohamed Ali Ben Romdhane",
        "Elias Achouri",
        "Seifeddine Jaziri"
    ]
)

print(result)
# Out:
# MatchPrediction(match_name='Sweden vs Tunisia', home='Sweden', away='Tunisia', venue='Estadio BBVA', city='Monterrey', altitude_m=540.0, travel_home_km=0.0, travel_away_km=0.0, rest_home_days=7.0, rest_away_days=7.0, xg_home=1.483, xg_away=1.319, prob_home_win=0.4061, prob_draw=0.2598, prob_away_win=0.3341, top_scorelines=[{'score': '1-1', 'probability': 0.1103}, {'score': '0-0', 'probability': 0.0879}, {'score': '1-0', 'probability': 0.0845}, {'score': '0-1', 'probability': 0.0748}, {'score': '2-1', 'probability': 0.0746}, {'score': '1-2', 'probability': 0.0686}, {'score': '2-0', 'probability': 0.0676}, {'score': '0-2', 'probability': 0.0537}, {'score': '2-2', 'probability': 0.049}, {'score': '3-1', 'probability': 0.0433}], lineup_home={'players': ['Kristoffer Nordfeldt', 'Victor Lindelof', 'Isak Hien', 'Gustaf Lagerbielke', 'Daniel Svensson', 'Hugo Larsson', 'Yasin Ayari', 'Gabriel Gudmundsson', 'Anthony Elanga', 'Alexander Isak', 'Viktor Gyokeres'], 'lineup_rating': 71.3, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Kristoffer Nordfeldt', 'matched': 'Bo Kristoffer Nordfeldt', 'ovr': 72.0, 'pos': 'GK'}, {'input': 'Victor Lindelof', 'matched': 'Victor Lindelof', 'ovr': 64.25882352941177, 'pos': 'MID'}, {'input': 'Isak Hien', 'matched': 'Isak Hien', 'ovr': 64.25882352941177, 'pos': 'MID'}, {'input': 'Gustaf Lagerbielke', 'matched': 'Gustaf Johan Lagerbielke', 'ovr': 71.0, 'pos': 'CB'}, {'input': 'Daniel Svensson', 'matched': 'Daniel Svensson', 'ovr': 77.0, 'pos': 'LB, CM, LM'}, {'input': 'Hugo Larsson', 'matched': 'H. Larsson', 'ovr': 78.0, 'pos': 'CM, CDM'}, {'input': 'Yasin Ayari', 'matched': 'Yasin Ayari', 'ovr': 64.25882352941177, 'pos': 'MID'}, {'input': 'Gabriel Gudmundsson', 'matched': 'Gabriel Gudmundsson', 'ovr': 77.0, 'pos': 'LB, LM, CB'}, {'input': 'Anthony Elanga', 'matched': 'Anthony Elanga', 'ovr': 64.25882352941177, 'pos': 'MID'}, {'input': 'Alexander Isak', 'matched': 'Alexander Isak', 'ovr': 88.0, 'pos': 'ST'}, {'input': 'Viktor Gyokeres', 'matched': 'Viktor Gyokeres', 'ovr': 64.25882352941177, 'pos': 'MID'}]}, lineup_away={'players': ['Aymen Dahmen', 'Montassar Talbi', 'Dylan Bronn', 'Hamza Ben Abda', 'Ali Abdi', 'Ellyes Skhiri', 'Hannibal Mejbri', 'Anis Ben Slimane', 'Mohamed Ali Ben Romdhane', 'Elias Achouri', 'Seifeddine Jaziri'], 'lineup_rating': 68.44, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Aymen Dahmen', 'matched': 'Aymen Dahmen', 'ovr': 68.44444444444444, 'pos': 'MID'}, {'input': 'Montassar Talbi', 'matched': 'Montassar Talbi', 'ovr': 68.44444444444444, 'pos': 'MID'}, {'input': 'Dylan Bronn', 'matched': 'Dylan Bronn', 'ovr': 68.44444444444444, 'pos': 'MID'}, {'input': 'Hamza Ben Abda', 'matched': 'Hamza Ben Abda', 'ovr': 68.44444444444444, 'pos': 'MID'}, {'input': 'Ali Abdi', 'matched': 'Ali Abdi', 'ovr': 68.44444444444444, 'pos': 'MID'}, {'input': 'Ellyes Skhiri', 'matched': 'Ellyes Skhiri', 'ovr': 68.44444444444444, 'pos': 'MID'}, {'input': 'Hannibal Mejbri', 'matched': 'Hannibal Mejbri', 'ovr': 68.44444444444444, 'pos': 'MID'}, {'input': 'Anis Ben Slimane', 'matched': 'Anis Ben Slimane', 'ovr': 68.44444444444444, 'pos': 'MID'}, {'input': 'Mohamed Ali Ben Romdhane', 'matched': 'Mohamed Ali Ben Romdhane', 'ovr': 68.44444444444444, 'pos': 'MID'}, {'input': 'Elias Achouri', 'matched': 'Elias Achouri', 'ovr': 68.44444444444444, 'pos': 'MID'}, {'input': 'Seifeddine Jaziri', 'matched': 'Seifeddine Jaziri', 'ovr': 68.44444444444444, 'pos': 'MID'}]}, model_version='dixon-coles-nb-v2')

# %%
from predict import predict_upcoming_match

result = predict_upcoming_match(
    match_name="Germany vs Curaçao",
    venue="NRG Stadium",
    lineup_home=[
        "Manuel Neuer",
        "Joshua Kimmich",
        "Jonathan Tah",
        "Nico Schlotterbeck",
        "Nathaniel Brown",
        "Aleksandar Pavlovic",
        "Felix Nmecha",
        "Leroy Sane",
        "Jamal Musiala",
        "Florian Wirtz",
        "Kai Havertz"
    ],
    lineup_away=[
        "Eloy Room",
        "Jurien Gaari",
        "Armando Obispo",
        "Riechedly Bazoer",
        "Sherel Floranus",
        "Livano Comenencia",
        "Leandro Bacuna",
        "Juninho Bacuna",
        "Deveron Fonville",
        "Tahith Chong",
        "Jurgen Locadia"
    ]
)

print(result)
# Out:
# MatchPrediction(match_name='Germany vs Curaçao', home='Germany', away='Curaçao', venue='NRG Stadium', city='Houston', altitude_m=15.0, travel_home_km=0.0, travel_away_km=0.0, rest_home_days=7.0, rest_away_days=7.0, xg_home=3.14, xg_away=0.926, prob_home_win=0.7638, prob_draw=0.144, prob_away_win=0.0922, top_scorelines=[{'score': '2-0', 'probability': 0.0903}, {'score': '3-0', 'probability': 0.0823}, {'score': '2-1', 'probability': 0.0692}, {'score': '3-1', 'probability': 0.0646}, {'score': '4-0', 'probability': 0.0604}, {'score': '1-1', 'probability': 0.0592}, {'score': '1-0', 'probability': 0.0561}, {'score': '4-1', 'probability': 0.0485}, {'score': '0-0', 'probability': 0.0404}, {'score': '5-0', 'probability': 0.0396}], lineup_home={'players': ['Manuel Neuer', 'Joshua Kimmich', 'Jonathan Tah', 'Nico Schlotterbeck', 'Nathaniel Brown', 'Aleksandar Pavlovic', 'Felix Nmecha', 'Leroy Sane', 'Jamal Musiala', 'Florian Wirtz', 'Kai Havertz'], 'lineup_rating': 73.61, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Manuel Neuer', 'matched': 'Manuel Neuer', 'ovr': 66.44334975369458, 'pos': 'MID'}, {'input': 'Joshua Kimmich', 'matched': 'Joshua Kimmich', 'ovr': 66.44334975369458, 'pos': 'MID'}, {'input': 'Jonathan Tah', 'matched': 'Jonathan Tah', 'ovr': 66.44334975369458, 'pos': 'MID'}, {'input': 'Nico Schlotterbeck', 'matched': 'N. Schlotterbeck', 'ovr': 85.0, 'pos': 'CB'}, {'input': 'Nathaniel Brown', 'matched': 'Nathaniel Brown', 'ovr': 77.0, 'pos': 'LB, LM'}, {'input': 'Aleksandar Pavlovic', 'matched': 'Aleksandar Pavlović', 'ovr': 79.0, 'pos': 'CDM, CM'}, {'input': 'Felix Nmecha', 'matched': 'Felix Nmecha', 'ovr': 66.44334975369458, 'pos': 'MID'}, {'input': 'Leroy Sane', 'matched': 'Leroy Sane', 'ovr': 66.44334975369458, 'pos': 'MID'}, {'input': 'Jamal Musiala', 'matched': 'Jamal Musiala', 'ovr': 88.0, 'pos': 'CAM, LM, CM, ST'}, {'input': 'Florian Wirtz', 'matched': 'Florian Wirtz', 'ovr': 66.44334975369458, 'pos': 'MID'}, {'input': 'Kai Havertz', 'matched': 'K. Havertz', 'ovr': 82.0, 'pos': 'ST, CM, CAM'}]}, lineup_away={'players': ['Eloy Room', 'Jurien Gaari', 'Armando Obispo', 'Riechedly Bazoer', 'Sherel Floranus', 'Livano Comenencia', 'Leandro Bacuna', 'Juninho Bacuna', 'Deveron Fonville', 'Tahith Chong', 'Jurgen Locadia'], 'lineup_rating': 70.27, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Eloy Room', 'matched': 'Eloy Room', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Jurien Gaari', 'matched': 'Jurien Gaari', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Armando Obispo', 'matched': 'Armando Obispo', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Riechedly Bazoer', 'matched': 'Riechedly Bazoer', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Sherel Floranus', 'matched': 'Sherel Floranus', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Livano Comenencia', 'matched': 'Livano Comenencia', 'ovr': 62.0, 'pos': 'RB, CB, CDM, RM'}, {'input': 'Leandro Bacuna', 'matched': 'Leandro Bacuna', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Juninho Bacuna', 'matched': 'Juninho Bacuna', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Deveron Fonville', 'matched': 'Deveron Fonville', 'ovr': 63.0, 'pos': 'LB, CB, LM'}, {'input': 'Tahith Chong', 'matched': 'Tahith Chong', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Jurgen Locadia', 'matched': 'Jurgen Locadia', 'ovr': 72.0, 'pos': 'MID'}]}, model_version='dixon-coles-nb-v2')
