# %%
from predict import predict_upcoming_match

result = predict_upcoming_match(
    match_name="United States vs Paraguay",
    venue="SoFi Stadium",
    lineup_home=[
        "Matt Freese",
        "Alex Freeman",
        "Chris Richards",
        "Tim Ream",
        "Antonee Robinson",
        "Sergino Dest",
        "Tyler Adams",
        "Weston McKennie",
        "Malik Tillman",
        "Christian Pulisic",
        "Folarin Balogun"
    ],
    lineup_away=[
        "Roberto Fernandez",
        "Juan Caceres",
        "Gustavo Gomez",
        "Omar Alderete",
        "Junior Alonso",
        "Andres Cubas",
        "Diego Gomez",
        "Alejandro Romero Gamarra",
        "Miguel Almiron",
        "Julio Enciso",
        "Antonio Sanabria"
    ]
)

print(result)
# Out:
# MatchPrediction(match_name='United States vs Paraguay', home='United States', away='Paraguay', venue='SoFi Stadium', city='Los Angeles', altitude_m=30.0, travel_home_km=0.0, travel_away_km=0.0, rest_home_days=7.0, rest_away_days=7.0, xg_home=1.546, xg_away=1.379, prob_home_win=0.3995, prob_draw=0.2682, prob_away_win=0.3323, top_scorelines=[{'score': '1-1', 'probability': 0.1116}, {'score': '0-0', 'probability': 0.0887}, {'score': '2-1', 'probability': 0.0782}, {'score': '1-0', 'probability': 0.0752}, {'score': '1-2', 'probability': 0.0679}, {'score': '0-1', 'probability': 0.0678}, {'score': '2-0', 'probability': 0.0637}, {'score': '0-2', 'probability': 0.0542}, {'score': '2-2', 'probability': 0.0509}, {'score': '3-1', 'probability': 0.0381}], lineup_home={'players': ['Matt Freese', 'Alex Freeman', 'Chris Richards', 'Tim Ream', 'Antonee Robinson', 'Sergino Dest', 'Tyler Adams', 'Weston McKennie', 'Malik Tillman', 'Christian Pulisic', 'Folarin Balogun'], 'lineup_rating': 66.6, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Matt Freese', 'matched': 'Matt Freese', 'ovr': 64.1948051948052, 'pos': 'MID'}, {'input': 'Alex Freeman', 'matched': 'A. Freeman', 'ovr': 65.0, 'pos': 'RB'}, {'input': 'Chris Richards', 'matched': 'Chris Richards', 'ovr': 64.1948051948052, 'pos': 'MID'}, {'input': 'Tim Ream', 'matched': 'T. Ream', 'ovr': 72.0, 'pos': 'CB, LB'}, {'input': 'Antonee Robinson', 'matched': 'Antonee Robinson', 'ovr': 82.0, 'pos': 'LB, LM'}, {'input': 'Sergino Dest', 'matched': 'Sergino Dest', 'ovr': 64.1948051948052, 'pos': 'MID'}, {'input': 'Tyler Adams', 'matched': 'Tyler Adams', 'ovr': 64.1948051948052, 'pos': 'MID'}, {'input': 'Weston McKennie', 'matched': 'Weston McKennie', 'ovr': 64.1948051948052, 'pos': 'MID'}, {'input': 'Malik Tillman', 'matched': 'Malik Tillman', 'ovr': 64.1948051948052, 'pos': 'MID'}, {'input': 'Christian Pulisic', 'matched': 'Christian Pulisic', 'ovr': 64.1948051948052, 'pos': 'MID'}, {'input': 'Folarin Balogun', 'matched': 'Folarin Balogun', 'ovr': 64.1948051948052, 'pos': 'MID'}]}, lineup_away={'players': ['Roberto Fernandez', 'Juan Caceres', 'Gustavo Gomez', 'Omar Alderete', 'Junior Alonso', 'Andres Cubas', 'Diego Gomez', 'Alejandro Romero Gamarra', 'Miguel Almiron', 'Julio Enciso', 'Antonio Sanabria'], 'lineup_rating': 68.26, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Roberto Fernandez', 'matched': 'Roberto Fernández Jaén', 'ovr': 74.0, 'pos': 'ST'}, {'input': 'Juan Caceres', 'matched': 'Juan Caceres', 'ovr': 66.36, 'pos': 'MID'}, {'input': 'Gustavo Gomez', 'matched': 'Gustavo Gomez', 'ovr': 66.36, 'pos': 'MID'}, {'input': 'Omar Alderete', 'matched': 'O. Alderete', 'ovr': 78.0, 'pos': 'CB'}, {'input': 'Junior Alonso', 'matched': 'Julio Alonso', 'ovr': 68.0, 'pos': 'LB, LM'}, {'input': 'Andres Cubas', 'matched': 'Andres Cubas', 'ovr': 66.36, 'pos': 'MID'}, {'input': 'Diego Gomez', 'matched': 'Diego Gomez', 'ovr': 66.36, 'pos': 'MID'}, {'input': 'Alejandro Romero Gamarra', 'matched': 'Alejandro Romero Gamarra', 'ovr': 66.36, 'pos': 'MID'}, {'input': 'Miguel Almiron', 'matched': 'Miguel Almiron', 'ovr': 66.36, 'pos': 'MID'}, {'input': 'Julio Enciso', 'matched': 'Julio Enciso', 'ovr': 66.36, 'pos': 'MID'}, {'input': 'Antonio Sanabria', 'matched': 'Antonio Sanabria', 'ovr': 66.36, 'pos': 'MID'}]}, model_version='dixon-coles-nb-v2')

# %%
from predict import predict_upcoming_match

result = predict_upcoming_match(
    match_name="Canada vs Bosnia and Herzegovina",
    venue="BMO Field",
    lineup_home=[
        "Maxime Crepeau",
        "Alistair Johnston",
        "Luc De Fougerolles",
        "Derek Cornelius",
        "Richie Laryea",
        "Tajon Buchanan",
        "Stephen Eustaquio",
        "Ismael Kone",
        "Liam Millar",
        "Jonathan David",
        "Cyle Larin"
    ],
    lineup_away=[
        "Nikola Vasilj",
        "Amar Dedic",
        "Nikola Katic",
        "Tarik Muharemovic",
        "Sead Kolasinac",
        "Esmir Bajraktarevic",
        "Benjamin Tahirovic",
        "Ivan Basic",
        "Amar Memic",
        "Ermedin Demirovic",
        "Edin Dzeko"
    ]
)

print(result)
# Out:
# MatchPrediction(match_name='Canada vs Bosnia and Herzegovina', home='Canada', away='Bosnia and Herzegovina', venue='BMO Field', city='Toronto', altitude_m=76.0, travel_home_km=0.0, travel_away_km=0.0, rest_home_days=7.0, rest_away_days=7.0, xg_home=1.713, xg_away=0.727, prob_home_win=0.5754, prob_draw=0.2708, prob_away_win=0.1538, top_scorelines=[{'score': '1-0', 'probability': 0.1325}, {'score': '0-0', 'probability': 0.1201}, {'score': '2-0', 'probability': 0.1195}, {'score': '1-1', 'probability': 0.1146}, {'score': '2-1', 'probability': 0.0805}, {'score': '3-0', 'probability': 0.0715}, {'score': '0-1', 'probability': 0.0566}, {'score': '3-1', 'probability': 0.0455}, {'score': '1-2', 'probability': 0.0361}, {'score': '2-2', 'probability': 0.0319}], lineup_home={'players': ['Maxime Crepeau', 'Alistair Johnston', 'Luc De Fougerolles', 'Derek Cornelius', 'Richie Laryea', 'Tajon Buchanan', 'Stephen Eustaquio', 'Ismael Kone', 'Liam Millar', 'Jonathan David', 'Cyle Larin'], 'lineup_rating': 64.82, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Maxime Crepeau', 'matched': 'Maxime Crépeau', 'ovr': 69.0, 'pos': 'GK'}, {'input': 'Alistair Johnston', 'matched': 'Alistair Johnston', 'ovr': 63.2, 'pos': 'MID'}, {'input': 'Luc De Fougerolles', 'matched': 'L. De Fougerolles', 'ovr': 60.0, 'pos': 'CB, RB, LB'}, {'input': 'Derek Cornelius', 'matched': 'D. Cornelius', 'ovr': 74.0, 'pos': 'CB'}, {'input': 'Richie Laryea', 'matched': 'Richie Laryea', 'ovr': 63.2, 'pos': 'MID'}, {'input': 'Tajon Buchanan', 'matched': 'Tajon Buchanan', 'ovr': 63.2, 'pos': 'MID'}, {'input': 'Stephen Eustaquio', 'matched': 'Stephen Eustáquio', 'ovr': 77.0, 'pos': 'CDM, CM, CB'}, {'input': 'Ismael Kone', 'matched': 'Ismael Konate', 'ovr': 57.0, 'pos': 'ST'}, {'input': 'Liam Millar', 'matched': 'Liam Möller', 'ovr': 60.0, 'pos': 'CAM, RW, CM'}, {'input': 'Jonathan David', 'matched': 'Jonathan David', 'ovr': 63.2, 'pos': 'MID'}, {'input': 'Cyle Larin', 'matched': 'Cyle Larin', 'ovr': 63.2, 'pos': 'MID'}]}, lineup_away={'players': ['Nikola Vasilj', 'Amar Dedic', 'Nikola Katic', 'Tarik Muharemovic', 'Sead Kolasinac', 'Esmir Bajraktarevic', 'Benjamin Tahirovic', 'Ivan Basic', 'Amar Memic', 'Ermedin Demirovic', 'Edin Dzeko'], 'lineup_rating': 72.97, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Nikola Vasilj', 'matched': 'Nikola Vasilj', 'ovr': 77.0, 'pos': 'GK'}, {'input': 'Amar Dedic', 'matched': 'Amar Dedić', 'ovr': 74.0, 'pos': 'RB, LB, RM'}, {'input': 'Nikola Katic', 'matched': 'Nikola Katić', 'ovr': 69.0, 'pos': 'CB'}, {'input': 'Tarik Muharemovic', 'matched': 'Tarik Muharemović', 'ovr': 70.0, 'pos': 'CB'}, {'input': 'Sead Kolasinac', 'matched': 'Sead Kolašinac', 'ovr': 79.0, 'pos': 'CB'}, {'input': 'Esmir Bajraktarevic', 'matched': 'Esmir Bajraktarević', 'ovr': 67.0, 'pos': 'RW, RM'}, {'input': 'Benjamin Tahirovic', 'matched': 'Benjamin Tahirović', 'ovr': 67.0, 'pos': 'CDM, CM'}, {'input': 'Ivan Basic', 'matched': 'Ivan Basic', 'ovr': 66.61538461538461, 'pos': 'MID'}, {'input': 'Amar Memic', 'matched': 'Amar Memić', 'ovr': 72.0, 'pos': 'RM, LM, RW'}, {'input': 'Ermedin Demirovic', 'matched': 'Ermedin Demirović', 'ovr': 80.0, 'pos': 'ST'}, {'input': 'Edin Dzeko', 'matched': 'Edin Džeko', 'ovr': 81.0, 'pos': 'ST'}]}, model_version='dixon-coles-nb-v2')

# %%
from predict import predict_upcoming_match

result = predict_upcoming_match(
    match_name="South Korea vs Czech Republic",
    venue="Guadalajara Stadium",
    lineup_home=[
        "Kim Seung-gyu",
        "Lee Gi-hyeok",
        "Han-beom Lee",
        "Kim Min-jae",
        "Lee Tae-seok",
        "Young-woo Seol",
        "Paik Seung-ho",
        "Hwang In-beom",
        "Lee Jae-sung",
        "Lee Kang-in",
        "Son Heung-min"
    ],
    lineup_away=[
        "Matej Kovar",
        "Robin Hranac",
        "Stepan Chaloupek",
        "Ladislav Krejci",
        "Vladimir Coufal",
        "Tomas Soucek",
        "David Pavelka",
        "Lukas Provod",
        "David Jurasek",
        "Pavel Sulc",
        "Patrik Schick"
    ]
)

print(result)
# Out:
# MatchPrediction(match_name='South Korea vs Czech Republic', home='South Korea', away='Czech Republic', venue='Guadalajara Stadium', city='Guadalajara', altitude_m=1568.0, travel_home_km=0.0, travel_away_km=0.0, rest_home_days=7.0, rest_away_days=7.0, xg_home=1.331, xg_away=1.18, prob_home_win=0.3824, prob_draw=0.2919, prob_away_win=0.3257, top_scorelines=[{'score': '1-1', 'probability': 0.1254}, {'score': '0-0', 'probability': 0.1113}, {'score': '1-0', 'probability': 0.0944}, {'score': '0-1', 'probability': 0.0865}, {'score': '2-1', 'probability': 0.0766}, {'score': '2-0', 'probability': 0.0695}, {'score': '1-2', 'probability': 0.0658}, {'score': '0-2', 'probability': 0.0575}, {'score': '2-2', 'probability': 0.0449}, {'score': '3-1', 'probability': 0.0329}], lineup_home={'players': ['Kim Seung-gyu', 'Lee Gi-hyeok', 'Han-beom Lee', 'Kim Min-jae', 'Lee Tae-seok', 'Young-woo Seol', 'Paik Seung-ho', 'Hwang In-beom', 'Lee Jae-sung', 'Lee Kang-in', 'Son Heung-min'], 'lineup_rating': 70.55, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Kim Seung-gyu', 'matched': 'Kim Seung-gyu', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Lee Gi-hyeok', 'matched': 'Lee Gi Hyeok', 'ovr': 69.0, 'pos': 'CB, CM, RM, CDM'}, {'input': 'Han-beom Lee', 'matched': 'Lee Han Beom', 'ovr': 69.0, 'pos': 'CB'}, {'input': 'Kim Min-jae', 'matched': 'Kim Min Jae', 'ovr': 48.0, 'pos': 'CDM, CM'}, {'input': 'Lee Tae-seok', 'matched': 'Lee Tae Seok', 'ovr': 69.0, 'pos': 'LB, LM'}, {'input': 'Young-woo Seol', 'matched': 'Young-woo Seol', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Paik Seung-ho', 'matched': 'Paik Seung Ho', 'ovr': 72.0, 'pos': 'CDM, CM'}, {'input': 'Hwang In-beom', 'matched': 'Hwang In Beom', 'ovr': 77.0, 'pos': 'CM, CDM, CAM'}, {'input': 'Lee Jae-sung', 'matched': 'Lee Jae Sung', 'ovr': 77.0, 'pos': 'CAM, CM'}, {'input': 'Lee Kang-in', 'matched': 'Lee Kang In', 'ovr': 79.0, 'pos': 'RW, CM, RM'}, {'input': 'Son Heung-min', 'matched': 'Son Heung-min', 'ovr': 72.0, 'pos': 'MID'}]}, lineup_away={'players': ['Matej Kovar', 'Robin Hranac', 'Stepan Chaloupek', 'Ladislav Krejci', 'Vladimir Coufal', 'Tomas Soucek', 'David Pavelka', 'Lukas Provod', 'David Jurasek', 'Pavel Sulc', 'Patrik Schick'], 'lineup_rating': 74.82, 'lineup_mode': 'confirmed', 'ovr_details': [{'input': 'Matej Kovar', 'matched': 'Matej Kovar', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Robin Hranac', 'matched': 'Robin Hranáč', 'ovr': 71.0, 'pos': 'CB'}, {'input': 'Stepan Chaloupek', 'matched': 'Stepan Chaloupek', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Ladislav Krejci', 'matched': 'Ladislav Krejčí', 'ovr': 78.0, 'pos': 'CB, CDM'}, {'input': 'Vladimir Coufal', 'matched': 'Vladimír Coufal', 'ovr': 73.0, 'pos': 'RB, RM'}, {'input': 'Tomas Soucek', 'matched': 'Tomas Soucek', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'David Pavelka', 'matched': 'David Pavelka', 'ovr': 72.0, 'pos': 'MID'}, {'input': 'Lukas Provod', 'matched': 'Lukáš Provod', 'ovr': 78.0, 'pos': 'CAM, CM, LM'}, {'input': 'David Jurasek', 'matched': 'David Jurásek', 'ovr': 73.0, 'pos': 'LB, LM'}, {'input': 'Pavel Sulc', 'matched': 'Pavel Šulc', 'ovr': 77.0, 'pos': 'CAM, LM, RM, CM'}, {'input': 'Patrik Schick', 'matched': 'Patrik Schick', 'ovr': 85.0, 'pos': 'ST'}]}, model_version='dixon-coles-nb-v2')
